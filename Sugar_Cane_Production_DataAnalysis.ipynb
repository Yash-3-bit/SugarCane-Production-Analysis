# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('List of Countries by Sugarcane Production.csv',index_col=0)
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America       768.678.382                  3.668,531
# 1     India           Asia       348.448.000                     260721
# 2     China           Asia       123.059.739                      88287
# 3  Thailand           Asia        87.468.496                  1.264,303
# 4  Pakistan           Asia        65.450.704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0        10.226.205             75.167,5
# 1         4.950.000             70.393,5
# 2         1.675.215             73.459,1
# 3         1.336.575             65.442,2
# 4         1.130.820               57.879

# %%
df
# Out:
#        Country      Continent Production (Tons) Production per Person (Kg)  \
# 0       Brazil  South America       768.678.382                  3.668,531
# 1        India           Asia       348.448.000                     260721
# 2        China           Asia       123.059.739                      88287
# 3     Thailand           Asia        87.468.496                  1.264,303
# 4     Pakistan           Asia        65.450.704                     324219
# ..         ...            ...               ...                        ...
# 98     Lebanon           Asia                97                         16
# 99    Djibouti         Africa                53                         51
# 100  Singapore           Asia                50                          9
# 101      Samoa        Oceania                12                          6
# 102      Syria           Asia                 1                          0
#
#     Acreage (Hectare) Yield (Kg / Hectare)
# ...

# %%
df.shape
# Out:
# (103, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Country                     103 non-null    object
#  1   Continent                   103 non-null    object
#  2   Production (Tons)           103 non-null    object
#  3   Production per Person (Kg)  103 non-null    object
#  4   Acreage (Hectare)           102 non-null    object
#  5   Yield (Kg / Hectare)        102 non-null    object
# dtypes: object(6)
# memory usage: 5.6+ KB

# %% [markdown]
# ## Data Cleaning

# %%
df['Production (Tons)'] = df['Production (Tons)'].str.replace('.','')
df['Production per Person (Kg)'] = df['Production per Person (Kg)'].str.replace('.','').str.replace(',','.')
df['Acreage (Hectare)'] = df['Acreage (Hectare)'].str.replace('.','')
df['Yield (Kg / Hectare)'] = df['Yield (Kg / Hectare)'].str.replace('.','').str.replace(',','.')
# Out:
# C:\Users\Yaswanth\AppData\Local\Temp\ipykernel_10620\2896038240.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Production (Tons)'] = df['Production (Tons)'].str.replace('.','')
# C:\Users\Yaswanth\AppData\Local\Temp\ipykernel_10620\2896038240.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Production per Person (Kg)'] = df['Production per Person (Kg)'].str.replace('.','').str.replace(',','.')
# ...

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                   3668.531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                   1264.303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205              75167.5
# 1           4950000              70393.5
# 2           1675215              73459.1
# 3           1336575              65442.2
# 4           1130820                57879

# %%
df.isnull().sum()
# Out:
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df[df['Acreage (Hectare)'].isnull()]
# Out:
#      Country Continent Production (Tons) Production per Person (Kg)  \
# 99  Djibouti    Africa                53                         51
#
#    Acreage (Hectare) Yield (Kg / Hectare)
# 99               NaN                  NaN

# %%
df.dropna().reset_index(inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                   3668.531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                   1264.303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205              75167.5
# 1           4950000              70393.5
# 2           1675215              73459.1
# 3           1336575              65442.2
# 4           1130820                57879

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                   3668.531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                   1264.303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205              75167.5
# 1           4950000              70393.5
# 2           1675215              73459.1
# 3           1336575              65442.2
# 4           1130820                57879

# %%
df.dtypes
# Out:
# Country                       object
# Continent                     object
# Production (Tons)             object
# Production per Person (Kg)    object
# Acreage (Hectare)             object
# Yield (Kg / Hectare)          object
# dtype: object

# %%
df['Production (Tons)'] = df['Production (Tons)'].astype(float)
df['Production per Person (Kg)'] = df['Production per Person (Kg)'].astype(float)
df['Acreage (Hectare)'] = df['Acreage (Hectare)'].astype(float)
df['Yield (Kg / Hectare)'] = df['Yield (Kg / Hectare)'].astype(float)

# %%
df.dtypes
# Out:
# Country                        object
# Continent                      object
# Production (Tons)             float64
# Production per Person (Kg)    float64
# Acreage (Hectare)             float64
# Yield (Kg / Hectare)          float64
# dtype: object

# %%
df.nunique()
# Out:
# Country                       103
# Continent                       6
# Production (Tons)             103
# Production per Person (Kg)    102
# Acreage (Hectare)             101
# Yield (Kg / Hectare)          102
# dtype: int64

# %% [markdown]
# ## Univariate Analysis

# %%
df.head()
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                    3668.531
# 1     India           Asia        348448000.0                  260721.000
# 2     China           Asia        123059739.0                   88287.000
# 3  Thailand           Asia         87468496.0                    1264.303
# 4  Pakistan           Asia         65450704.0                  324219.000
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5
# 1          4950000.0               70393.5
# 2          1675215.0               73459.1
# 3          1336575.0               65442.2
# 4          1130820.0               57879.0

# %% [markdown]
# ## how many countries produce sugarcane from each continent?

# %%
df['Continent'].value_counts()
# Out:
# Africa           39
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: Continent, dtype: int64

# %%
df['Continent'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot(df['Production (Tons)'])

plt.subplot(2,2,2)
sns.distplot(df['Acreage (Hectare)'])

plt.subplot(2,2,3)
sns.distplot(df['Production per Person (Kg)'])

plt.subplot(2,2,4)
sns.distplot(df['Yield (Kg / Hectare)'])
# Out:
# C:\Users\Yaswanth\AppData\Local\Temp\ipykernel_10620\3813088480.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Production (Tons)'])
# C:\Users\Yaswanth\AppData\Local\Temp\ipykernel_10620\3813088480.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(df['Production (Tons)'])

plt.subplot(2,2,2)
sns.boxplot(df['Acreage (Hectare)'])

plt.subplot(2,2,3)
sns.boxplot(df['Production per Person (Kg)'])

plt.subplot(2,2,4)
sns.boxplot(df['Yield (Kg / Hectare)'])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        Production (Tons)  Production per Person (Kg)  Acreage (Hectare)  \
# count       1.030000e+02                  103.000000       1.020000e+02
# mean        1.832407e+07               111856.305311       2.498981e+05
# std         8.379760e+07               176134.928689       1.137003e+06
# min         1.000000e+00                    0.000000       0.000000e+00
# 25%         4.298850e+04                 3364.869000       1.104000e+03
# 50%         1.422432e+06                25481.000000       1.655800e+04
# 75%         6.145648e+06               144004.500000       8.047400e+04
# max         7.686784e+08               951087.000000       1.022620e+07
#
#        Yield (Kg / Hectare)
# count            102.000000
# mean           52628.078431
# std            30504.676683
# min               10.000000
# 25%            29072.025000
# 50%            54108.950000
# 75%            73282.700000
# max           129049.300000

# %% [markdown]
# ## which country produces maximum sugarcane?

# %%
df.head()
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                    3668.531
# 1     India           Asia        348448000.0                  260721.000
# 2     China           Asia        123059739.0                   88287.000
# 3  Thailand           Asia         87468496.0                    1264.303
# 4  Pakistan           Asia         65450704.0                  324219.000
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5
# 1          4950000.0               70393.5
# 2          1675215.0               73459.1
# 3          1336575.0               65442.2
# 4          1130820.0               57879.0

# %%
df['Production (Tons)'].ascending=False

# %%
df.head()
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                    3668.531
# 1     India           Asia        348448000.0                  260721.000
# 2     China           Asia        123059739.0                   88287.000
# 3  Thailand           Asia         87468496.0                    1264.303
# 4  Pakistan           Asia         65450704.0                  324219.000
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5
# 1          4950000.0               70393.5
# 2          1675215.0               73459.1
# 3          1336575.0               65442.2
# 4          1130820.0               57879.0

# %%
df['Production (Tons)'].max()
# Out:
# 768678382.0

# %%
df['Country'].nunique()
# Out:
# 103

# %%
df[df['Country']=='India']
# Out:
#   Country Continent  Production (Tons)  Production per Person (Kg)  \
# 1   India      Asia        348448000.0                    260721.0
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 1          4950000.0               70393.5

# %%
df[df['Production (Tons)']==768678382.0]
# Out:
#   Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0  Brazil  South America        768678382.0                    3668.531
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5

# %%
df['Production (Tons)'].describe()
# Out:
# count    1.030000e+02
# mean     1.832407e+07
# std      8.379760e+07
# min      1.000000e+00
# 25%      4.298850e+04
# 50%      1.422432e+06
# 75%      6.145648e+06
# max      7.686784e+08
# Name: Production (Tons), dtype: float64

# %%
df_n = df[['Country','Production (Tons)']].set_index('Country')
df_n
# Out:
#            Production (Tons)
# Country
# Brazil           768678382.0
# India            348448000.0
# China            123059739.0
# Thailand          87468496.0
# Pakistan          65450704.0
# ...                      ...
# Lebanon                 97.0
# Djibouti                53.0
# Singapore               50.0
# Samoa                   12.0
# Syria                    1.0
#
# [103 rows x 1 columns]

# %%
df_n['Production (Tons)_percent'] = df_n['Production (Tons)']*100/df['Production (Tons)'].sum()

# %%
df_n
# Out:
#            Production (Tons)  Production (Tons)_percent
# Country
# Brazil           768678382.0               4.072728e+01
# India            348448000.0               1.846200e+01
# China            123059739.0               6.520138e+00
# Thailand          87468496.0               4.634389e+00
# Pakistan          65450704.0               3.467809e+00
# ...                      ...                        ...
# Lebanon                 97.0               5.139401e-06
# Djibouti                53.0               2.808126e-06
# Singapore               50.0               2.649176e-06
# Samoa                   12.0               6.358022e-07
# Syria                    1.0               5.298352e-08
#
# [103 rows x 2 columns]

# %%
df_n['Production (Tons)_percent'].plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Production (Tons)_percent'>

# %%
df_n['Production (Tons)_percent'].head().plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
ax = sns.barplot(data=df.head(10),x='Country',y='Production (Tons)')
ax
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %%
ax
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# ## which country has highest land.

# %%
df['Acreage (Hectare)'].max()
# Out:
# 10226205.0

# %%
df.loc[df['Acreage (Hectare)']==10226205.0,['Country','Yield (Kg / Hectare)']]
# Out:
#   Country  Yield (Kg / Hectare)
# 0  Brazil               75167.5

# %%
ax = sns.barplot(data=df.head(10),x='Country',y='Yield (Kg / Hectare)')
ax
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %%
df.head(10)
# Out:
#                     Country      Continent  Production (Tons)  \
# 0                    Brazil  South America        768678382.0
# 1                     India           Asia        348448000.0
# 2                     China           Asia        123059739.0
# 3                  Thailand           Asia         87468496.0
# 4                  Pakistan           Asia         65450704.0
# 5                    Mexico  North America         56446821.0
# 6                  Colombia  South America         36951213.0
# 7                 Australia        Oceania         34403004.0
# 8                 Guatemala  North America         33533403.0
# 9  United States of America  North America         29926210.0
#
#    Production per Person (Kg)  Acreage (Hectare)  Yield (Kg / Hectare)
# 0                    3668.531         10226205.0               75167.5
# 1                  260721.000          4950000.0               70393.5
# ...

# %%
df_acr = df['Acreage (Hectare)'].sort_values(ascending=False)

# %%
df_acr.head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
df.head()
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                    3668.531
# 1     India           Asia        348448000.0                  260721.000
# 2     China           Asia        123059739.0                   88287.000
# 3  Thailand           Asia         87468496.0                    1264.303
# 4  Pakistan           Asia         65450704.0                  324219.000
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5
# 1          4950000.0               70393.5
# 2          1675215.0               73459.1
# 3          1336575.0               65442.2
# 4          1130820.0               57879.0

# %%
df_pro = df.copy()

# %%
df_pro.head()
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                    3668.531
# 1     India           Asia        348448000.0                  260721.000
# 2     China           Asia        123059739.0                   88287.000
# 3  Thailand           Asia         87468496.0                    1264.303
# 4  Pakistan           Asia         65450704.0                  324219.000
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5
# 1          4950000.0               70393.5
# 2          1675215.0               73459.1
# 3          1336575.0               65442.2
# 4          1130820.0               57879.0

# %%
df_pro.head()
# Out:
# 25    951087.0
# 6     740075.0
# 55    597066.0
# 42    581814.0
# 51    521254.0
# Name: Production per Person (Kg), dtype: float64

# %%
df_pro.tail()
# Out:
# 98     16.0
# 100     9.0
# 97      8.0
# 101     6.0
# 102     0.0
# Name: Production per Person (Kg), dtype: float64

# %%
df_pro2 = df.copy()

# %%
df_pro2.head()
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                    3668.531
# 1     India           Asia        348448000.0                  260721.000
# 2     China           Asia        123059739.0                   88287.000
# 3  Thailand           Asia         87468496.0                    1264.303
# 4  Pakistan           Asia         65450704.0                  324219.000
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5
# 1          4950000.0               70393.5
# 2          1675215.0               73459.1
# 3          1336575.0               65442.2
# 4          1130820.0               57879.0

# %%
df.head()
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                    3668.531
# 1     India           Asia        348448000.0                  260721.000
# 2     China           Asia        123059739.0                   88287.000
# 3  Thailand           Asia         87468496.0                    1264.303
# 4  Pakistan           Asia         65450704.0                  324219.000
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5
# 1          4950000.0               70393.5
# 2          1675215.0               73459.1
# 3          1336575.0               65442.2
# 4          1130820.0               57879.0

# %%
df.head()
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                    3668.531
# 1     India           Asia        348448000.0                  260721.000
# 2     China           Asia        123059739.0                   88287.000
# 3  Thailand           Asia         87468496.0                    1264.303
# 4  Pakistan           Asia         65450704.0                  324219.000
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5
# 1          4950000.0               70393.5
# 2          1675215.0               73459.1
# 3          1336575.0               65442.2
# 4          1130820.0               57879.0

# %%
df_pro2.sort_values(['Production per Person (Kg)'],ascending=False,inplace=True)

# %%
df_pro2.head()
# Out:
#                 Country      Continent  Production (Tons)  \
# 25             Paraguay  South America          6708000.0
# 6              Colombia  South America         36951213.0
# 55  Trinidad and Tobago  North America              810.0
# 42               Panama  North America          2419638.0
# 51              Jamaica  North America          1422432.0
#
#     Production per Person (Kg)  Acreage (Hectare)  Yield (Kg / Hectare)
# 25                    951087.0              120.0                 559.0
# 6                     740075.0           416626.0               88691.5
# 55                    597066.0               15.0                  54.0
# 42                    581814.0            37995.0               63683.1
# 51                    521254.0            26255.0               54178.2

# %%
df_pro2.reset_index(inplace=True)

# %%
df_pro2.head()
# Out:
#    index              Country      Continent  Production (Tons)  \
# 0     25             Paraguay  South America          6708000.0
# 1      6             Colombia  South America         36951213.0
# 2     55  Trinidad and Tobago  North America              810.0
# 3     42               Panama  North America          2419638.0
# 4     51              Jamaica  North America          1422432.0
#
#    Production per Person (Kg)  Acreage (Hectare)  Yield (Kg / Hectare)
# 0                    951087.0              120.0                 559.0
# 1                    740075.0           416626.0               88691.5
# 2                    597066.0               15.0                  54.0
# 3                    581814.0            37995.0               63683.1
# 4                    521254.0            26255.0               54178.2

# %%
df_pro2.drop(["index"],axis=1,inplace=True)

# %%
df_pro2.head()
# Out:
#                Country      Continent  Production (Tons)  \
# 0             Paraguay  South America          6708000.0
# 1             Colombia  South America         36951213.0
# 2  Trinidad and Tobago  North America              810.0
# 3               Panama  North America          2419638.0
# 4              Jamaica  North America          1422432.0
#
#    Production per Person (Kg)  Acreage (Hectare)  Yield (Kg / Hectare)
# 0                    951087.0              120.0                 559.0
# 1                    740075.0           416626.0               88691.5
# 2                    597066.0               15.0                  54.0
# 3                    581814.0            37995.0               63683.1
# 4                    521254.0            26255.0               54178.2

# %%
df.corr()
# Out:
# C:\Users\Yaswanth\AppData\Local\Temp\ipykernel_10620\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                             Production (Tons)  Production per Person (Kg)  \
# Production (Tons)                    1.000000                    0.016341
# Production per Person (Kg)           0.016341                    1.000000
# Acreage (Hectare)                    0.997550                    0.012557
# Yield (Kg / Hectare)                 0.132812                    0.017999
#
#                             Acreage (Hectare)  Yield (Kg / Hectare)
# Production (Tons)                    0.997550              0.132812
# Production per Person (Kg)           0.012557              0.017999
# Acreage (Hectare)                    1.000000              0.113433
# ...

# %% [markdown]
# ## do countries with higest land produce more sugar cane?

# %%
sns.heatmap(df.corr(),annot=True,cmap='Greens')
# Out:
# C:\Users\Yaswanth\AppData\Local\Temp\ipykernel_10620\3918344314.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='Greens')
# <Axes: >

# %%
sns.scatterplot(data=df,x='Acreage (Hectare)',y='Production (Tons)')
# Out:
# <Axes: xlabel='Acreage (Hectare)', ylabel='Production (Tons)'>

# %% [markdown]
# ## Analysis for Continent

# %%
df_cont = df.copy()

# %%
conti = df_cont.groupby('Continent').sum()
conti
# Out:
# C:\Users\Yaswanth\AppData\Local\Temp\ipykernel_10620\2325240220.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   conti = df_cont.groupby('Continent').sum()
#                Production (Tons)  Production per Person (Kg)  \
# Continent
# Africa                89681525.0                 2332687.293
# Asia                 721930425.0                 1857769.303
# Europe                    5823.0                     536.000
# North America        173995947.0                 3796081.508
# Oceania               36177574.0                   28593.605
# South America        865588126.0                 3505531.738
#
#                Acreage (Hectare)  Yield (Kg / Hectare)
# Continent
# Africa                 1439089.0             2142107.5
# Asia                  10608319.0             1171871.4
# ...

# %% [markdown]
# ## which continent producesw max sugarcane??

# %%
df_cont.groupby('Continent')['Production (Tons)'].describe()
# Out:
#                count          mean           std     min         25%  \
# Continent
# Africa          39.0  2.299526e+06  3.594392e+06    53.0   217076.00
# Asia            25.0  2.887722e+07  7.341752e+07     1.0     1186.00
# Europe           2.0  2.911500e+03  3.560283e+03   394.0     1652.75
# North America   22.0  7.908907e+06  1.441856e+07    10.0     9922.50
# Oceania          4.0  9.044394e+06  1.691974e+07    12.0   163402.50
# South America   11.0  7.868983e+07  2.291034e+08  3677.0  2862902.50
#
#                      50%          75%          max
# Continent
# Africa          687365.0   2999884.00   15760418.0
# Asia           1574000.0  16313145.00  348448000.0
# Europe            2911.5      4170.25       5429.0
# North America  1465184.0   6450285.25   56446821.0
# Oceania         887279.0   9768270.00   34403004.0
# South America  6910805.0  15911674.50  768678382.0

# %%
conti['Production (Tons)'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %%
conti['Production (Tons)'].sort_values(ascending=False)
# Out:
# Continent
# South America    865588126.0
# Asia             721930425.0
# North America    173995947.0
# Africa            89681525.0
# Oceania           36177574.0
# Europe                5823.0
# Name: Production (Tons), dtype: float64

# %% [markdown]
# ## do number of countries in a continent effects production of sugercane?

# %%
df.groupby('Country')[['Continent','Production (Tons)']].sum()
# Out:
# C:\Users\Yaswanth\AppData\Local\Temp\ipykernel_10620\3401649022.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Country')[['Continent','Production (Tons)']].sum()
#                      Production (Tons)
# Country
# Afghanistan                    17364.0
# Angola                        556094.0
# Antigua and Barbuda             5365.0
# Argentina                   21990823.0
# Australia                   34403004.0
# ...                                ...
# Venezuela                    3331252.0
# Vietnam                     16313145.0
# Yemen                            500.0
# Zambia                       4285839.0
# Zimbabwe                     3483000.0
#
# [103 rows x 1 columns]

# %%
df.groupby('Continent').get_group('Asia')
# Out:
#          Country Continent  Production (Tons)  Production per Person (Kg)  \
# 1          India      Asia        348448000.0                  260721.000
# 2          China      Asia        123059739.0                   88287.000
# 3       Thailand      Asia         87468496.0                    1264.303
# 4       Pakistan      Asia         65450704.0                  324219.000
# 10     Indonesia      Asia         27158830.0                   10248.000
# 11   Philippines      Asia         22370546.0                  210232.000
# 14       Vietnam      Asia         16313145.0                  172334.000
# 17       Myanmar      Asia         10437058.0                  193771.000
# 20          Iran      Asia          7687593.0                    9403.000
# 30         Nepal      Asia          4346754.0                  148765.000
# 32    Bangladesh      Asia          4207592.0                   25481.000
# 45          Laos      Asia          2019000.0                  290036.000
# ...
